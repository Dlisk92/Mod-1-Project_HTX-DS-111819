# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('clean_df.csv')

# %%
df.isna()
# Out:
#       Unnamed: 0  budget  genres     id  imdb_id  original_title  popularity  \
# 0          False   False   False  False    False           False       False
# 1          False   False   False  False    False           False       False
# 2          False   False   False  False    False           False       False
# 3          False   False   False  False    False           False       False
# 4          False   False   False  False    False           False       False
# ...          ...     ...     ...    ...      ...             ...         ...
# 5751       False   False   False  False     True           False       False
# 5752       False   False   False  False    False           False       False
# 5753       False   False   False  False    False           False       False
# 5754       False   False   False  False     True           False       False
# 5755       False   False   False  False    False           False       False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5756 entries, 0 to 5755
# Data columns (total 15 columns):
# Unnamed: 0              5756 non-null int64
# budget                  5722 non-null float64
# genres                  5722 non-null object
# id                      5722 non-null float64
# imdb_id                 4311 non-null object
# original_title          5722 non-null object
# popularity              5722 non-null float64
# production_companies    5722 non-null object
# production_countries    5722 non-null object
# release_date            5722 non-null object
# revenue                 5722 non-null float64
# runtime                 5252 non-null float64
# title                   5722 non-null object
# vote_average            5722 non-null float64
# vote_count              5722 non-null float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 674.7+ KB

# %%
na_drop = df.dropna()

# %%
na_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4005 entries, 0 to 5753
# Data columns (total 15 columns):
# Unnamed: 0              4005 non-null int64
# budget                  4005 non-null float64
# genres                  4005 non-null object
# id                      4005 non-null float64
# imdb_id                 4005 non-null object
# original_title          4005 non-null object
# popularity              4005 non-null float64
# production_companies    4005 non-null object
# production_countries    4005 non-null object
# release_date            4005 non-null object
# revenue                 4005 non-null float64
# runtime                 4005 non-null float64
# title                   4005 non-null object
# vote_average            4005 non-null float64
# vote_count              4005 non-null float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 500.6+ KB

# %%
na_drop.head()
# Out:
#    Unnamed: 0       budget                                             genres  \
# 0           0  300000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 1           1  200000000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2           2  170000000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3           3  200000000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4           4  160000000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#          id    imdb_id                  original_title  popularity  \
# 0  299536.0  tt4154756          Avengers: Infinity War      76.719
# 1  284054.0  tt1825683                   Black Panther      36.027
# 2  351286.0  tt4881806  Jurassic World: Fallen Kingdom      34.309
# 3  260513.0  tt3606756                   Incredibles 2      26.936
# 4  297802.0  tt1477834                         Aquaman      28.084
#
#                                 production_companies  \
# ...

# %%
to_drop = na_drop[na_drop['revenue'] == 0]
to_drop
# Out:
#       Unnamed: 0   budget                                             genres  \
# 262          262      0.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 263          263    500.0                                                 []
# 264          264      0.0                 [{'id': 10749, 'name': 'Romance'}]
# 269          269      0.0                                                 []
# 271          271   2500.0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# ...          ...      ...                                                ...
# 5741        5741      0.0                [{'id': 99, 'name': 'Documentary'}]
# 5742        5742      0.0                                                 []
# 5745        5745  30000.0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 5752        5752      0.0                                                 []
# 5753        5753      0.0                                                 []
#
# ...

# %%
na_drop = na_drop[na_drop.revenue != 0]

# %%
na_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237 entries, 0 to 261
# Data columns (total 15 columns):
# Unnamed: 0              237 non-null int64
# budget                  237 non-null float64
# genres                  237 non-null object
# id                      237 non-null float64
# imdb_id                 237 non-null object
# original_title          237 non-null object
# popularity              237 non-null float64
# production_companies    237 non-null object
# production_countries    237 non-null object
# release_date            237 non-null object
# revenue                 237 non-null float64
# runtime                 237 non-null float64
# title                   237 non-null object
# vote_average            237 non-null float64
# vote_count              237 non-null float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 29.6+ KB

# %%
na_drop = na_drop[na_drop.budget != 0]

# %%
na_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184 entries, 0 to 261
# Data columns (total 15 columns):
# Unnamed: 0              184 non-null int64
# budget                  184 non-null float64
# genres                  184 non-null object
# id                      184 non-null float64
# imdb_id                 184 non-null object
# original_title          184 non-null object
# popularity              184 non-null float64
# production_companies    184 non-null object
# production_countries    184 non-null object
# release_date            184 non-null object
# revenue                 184 non-null float64
# runtime                 184 non-null float64
# title                   184 non-null object
# vote_average            184 non-null float64
# vote_count              184 non-null float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 23.0+ KB

# %%
na_drop.duplicated(subset='title').sum()
# Out:
# 19

# %%
na_drop['ROI'] = na_drop['revenue'] / na_drop['budget']
# to create a new column called ROI to acclount for rate of return

# %%
na_drop.tail(50)
# Out:
#      Unnamed: 0      budget  \
# 141         141  10000000.0
# 146         146  30000000.0
# 147         147   1000000.0
# 150         150  30000000.0
# 154         154    258157.0
# 155         155  20000000.0
# 156         156   4900000.0
# 159         159   2123894.0
# 160         160  35000000.0
# 161         161   4000000.0
# 162         162  19000000.0
# 163         163  10000000.0
# 164         164  10000000.0
# 165         165  35000000.0
# 166         166   1000000.0
# 172         172   3000000.0
# 174         174   3500000.0
# 175         175   8000000.0
# 178         178   2000000.0
# 180         180   2000000.0
# 184         184   9800000.0
# 188         188   6000000.0
# 193         193    900000.0
# 198         198   5000000.0
# 199         199   1200000.0
# 202         202   8000000.0
# 203         203     10000.0
# 208         208     50000.0
# 211         211        10.0
# 213         213     10000.0
# 214         214     10000.0
# 215         215     10000.0
# ...

# %%
na_drop.describe()
# Out:
#        Unnamed: 0        budget             id  popularity       revenue  \
# count  184.000000  1.840000e+02     184.000000  184.000000  1.840000e+02
# mean   103.891304  5.301079e+07  430513.652174   17.347908  2.187328e+08
# std     69.256624  6.483408e+07   84890.788320   11.957976  3.673415e+08
# min      0.000000  1.000000e+00   50022.000000    0.600000  1.000000e+00
# 25%     47.750000  5.875000e+06  375506.500000   10.297750  7.799362e+06
# 50%     93.500000  3.000000e+07  433428.000000   15.716000  5.258971e+07
# 75%    151.000000  7.500000e+07  474350.000000   21.995250  2.936931e+08
# max    261.000000  3.000000e+08  650157.000000   76.719000  2.046240e+09
#
#           runtime  vote_average    vote_count           ROI
# count  184.000000    184.000000    184.000000    184.000000
# mean   107.157609      6.122826   2334.418478     60.663082
# std     27.001764      1.911147   3047.907035    737.028913
# min      5.000000      0.000000      0.000000      0.000349
# ...

# %%
# budget less that 10000 seems suspect
by_budget = na_drop[na_drop['budget'] > 10000]

# %%
by_budget.reset_index(drop=True)
# Out:
#      Unnamed: 0       budget  \
# 0             0  300000000.0
# 1             1  200000000.0
# 2             2  170000000.0
# 3             3  200000000.0
# 4             4  160000000.0
# ..          ...          ...
# 159         202    8000000.0
# 160         208      50000.0
# 161         229     130178.0
# 162         230   13000000.0
# 163         234    2000000.0
#
#                                                 genres        id    imdb_id  \
# 0    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  299536.0  tt4154756
# 1    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  284054.0  tt1825683
# 2    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  351286.0  tt4881806
# 3    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  260513.0  tt3606756
# 4    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  297802.0  tt1477834
# ..                                                 ...       ...        ...
# ...

# %%
by_budget = by_budget[by_budget['ROI'] != 262.5]
#no outside data supports the revenue claimed in this movie

# %%
by_budget = by_budget[by_budget['vote_count'] !=0]
#removing movies that no one rated

# %%
by_budget['genres'].value_counts()
# Out:
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 878, 'name': 'Science Fiction'}]                                    6
# [{'id': 35, 'name': 'Comedy'}]                                                                                                             6
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]                                                                                4
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}]                                             3
# [{'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}]                                                                     3
#                                                                                                                                           ..
# ...

# %%
by_budget.index[]
# Out:
#   File "<ipython-input-23-6288e2270677>", line 1
#     by_budget.index[]
#                     ^
# SyntaxError: invalid syntax

# %%
by_budget.describe()
# Out:
#        Unnamed: 0        budget             id  popularity       revenue  \
# count  162.000000  1.620000e+02     162.000000  162.000000  1.620000e+02
# mean    87.537037  6.020853e+07  411839.462963   19.589377  2.483023e+08
# std     55.695505  6.589274e+07   69324.586519   10.964878  3.821230e+08
# min      0.000000  1.301780e+05   50022.000000    2.407000  2.231000e+03
# 25%     42.250000  1.262500e+07  363088.000000   13.359000  1.927428e+07
# 50%     82.500000  3.450000e+07  426553.000000   16.619000  7.277117e+07
# 75%    126.750000  8.950000e+07  458551.250000   23.792250  3.506516e+08
# max    234.000000  3.000000e+08  548786.000000   76.719000  2.046240e+09
#
#           runtime  vote_average    vote_count         ROI
# count  162.000000    162.000000    162.000000  162.000000
# mean   112.981481      6.540741   2651.351852    4.455658
# std     17.209153      0.859044   3116.700823    6.884162
# min     78.000000      3.000000      2.000000    0.000349
# ...

# %%
by_budget.to_csv('clean_df_v2.csv')

# %%
by_budget.tail()['genres']
# Out:
# 199    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 202    [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 229    [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 230    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 234    [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# Name: genres, dtype: object
